# %% [markdown]
# <a href="https://colab.research.google.com/github/cjh060331/ABCD-A/blob/20250317/test4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
>>> 4/3
# Out:
# 1.3333333333333333

# %%
>>> 1/2
# Out:
# 0.5

# %%
>>> 4/2
# Out:
# 2.0

# %%
>>> 7//3 #몫
# Out:
# 2

# %%
>>> 7%3 #나머지
# Out:
# 1

# %%
>>> 2**10 #제곱
# Out:
# 1024

# %%
>>> int(5/2)
# Out:
# 2

# %%
>>> 5 // 2
# Out:
# 2

# %%
a = 11+2
b = 12-2
c = 13*2
d = 14/2
e = 15**2
f = 16//2
g = 17%3
print(a,b,c,d,e,f,g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
i = 3
i += 3
print(i)
i -= 3
print(i)
i *=2
print(i)
i /=2
print(int (i))
i = 3
i %=2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1

# %%
a = 10
b = 3
print("10 == 3 =>", a==b)
print("10 != 3 =>", a!=b)
print("10 > 3 =>", a>b)
print("10 > =3 =>", a>=b)
print("10 < 3 =>", a<b)
print("10 <= 3 =>", a <=b)
print()
# Out:
# 10 == 3 => False
# 10 != 3 => True
# 10 > 3 => True
# 10 > =3 => True
# 10 < 3 => False
# 10 <= 3 => False

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
# Out:
# 0b1101
# 0b1001
# 0b1001
# 9

# %%
a = 12
b = 8
print(bin(a))
print(bin(b))
print(bin(a^b))
print('')
print(a^b)
# Out:
# 0b1100
# 0b1000
# 0b100
#
# 4

# %%
a = 12
b = 8
print(bin(a))
print(bin(~a))
# Out:
# 0b1100
# -0b1101
