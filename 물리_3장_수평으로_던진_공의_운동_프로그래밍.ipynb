# %% [markdown]
# <a href="https://colab.research.google.com/github/cjh060331/ABCD-A/blob/20250415/%EB%AC%BC%EB%A6%AC_3%EC%9E%A5_%EC%88%98%ED%8F%89%EC%9C%BC%EB%A1%9C_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

#변수 선언

g = 9.8; # 중력가속도 (m/s^2)
a = -g; # 가속도 = -중력가속도
v0 = 0; # 초기속도 (m/s)
PI = 3.141592; # 파이 = 3.141592;

#초기 속도 입력
v0 = float(input())
print("초기속도 : ", v0,"m/s")
# Out:
# 30
# 초기속도 :  30.0 m/s

# %%
#초기 각도
angle_degree = float(input())
print("초기 각도 : ", angle_degree,"도")

#각도를 radian으로 변환
angle_radian = angle_degree * PI / 180
print("초기 각도 : ", angle_radian,"radian")
# Out:
# 30
# 초기 각도 :  30.0 도
# 초기 각도 :  0.5235986666666667 radian

# %%
# x 성분의 속도를 구하세요
v0x = math.cos(angle_radian) * v0
print("x축의 초기속도 : ", v0x , "m/s")
# Out:
# x축의 초기속도 :  25.98076374750749 m/s

# %%
# y 성분의 속도를 구하세요
v0y = math.sin(angle_radian) * v0
print("y축의 초기 속도 : ", v0y, "m/s")
# Out:
# y축의 초기 속도 :  14.999997169873087 m/s

# %%
# 최고점 높이

H = (v0y ** 2)/(2*g)
print("최고점 높이:",H,"m")
# Out:
# 최고점 높이: 11.479587504908194 m

# %%
# 최고점에 도착하는 시간을 구하여라
t = v0y / g
print("최고점 도달 시간:", t, "초")
# Out:
# 최고점 도달 시간: 1.5306119561094986 초

# %%
# 수평으로 이동한 최고 거리를 구하여라
x = v0x * t * 2
print("수평으로 이동한 최대거리:", x ,"m")
# Out:
# 수평으로 이동한 최대거리: 79.53293524158236 m

# %%
# 지면 도착 시 속도 벡터(x,y, 전체 속도)
vx_final = v0x
vy_final = -v0y
v_final = math.sqrt(vx_final**2 + vy_final**2)
print("지면 도착 시 vx: ", vx_final,"m/s")
print("지면 도착시 vy: ", vy_final,"m/s")
print("지면 도착시 속도 벡터 크기 v:", v_final, "m/s")
# Out:
# 지면 도착 시 vx:  25.98076374750749 m/s
# 지면 도착시 vy:  -14.999997169873087 m/s
# 지면 도착시 속도 벡터 크기 v: 30.0 m/s
