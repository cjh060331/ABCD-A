# %% [markdown]
# <a href="https://colab.research.google.com/github/cjh060331/ABCD-A/blob/20250310/%ED%8C%8C%EC%9D%B4%EC%8D%AC300%EC%A0%9C_1_10%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4_2025_03_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello wolrd")
# Out:
# Hello wolrd

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리를 질렀다."도둑이야"')
# Out:
# 신씨가 소리를 질렀다."도둑이야"

# %%
print('"C:\Windows"')
# Out:
# "C:\Windows"

# %%
print("안녕하세요.|n만나서|t|t반갑습니다.")
# Out:
# 안녕하세요.|n만나서|t|t반갑습니다.

# %%
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
print("never", "kakao", "sk", "samsung", sep=';')
# Out:
# never;kakao;sk;samsung

# %%
print("never", "kakao", "sk", "samsung", sep='/')
# Out:
# never/kakao/sk/samsung

# %%
print("first", end="");print("second")
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667
