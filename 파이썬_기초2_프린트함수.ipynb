# %% [markdown]
# <a href="https://colab.research.google.com/github/cjh060331/ABCD-A/blob/20250314/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%882_%ED%94%84%EB%A6%B0%ED%8A%B8%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print('hello' , 'everyone')
print("hello" + "everyone")
# Out:
# hello
# hello everyone
# helloeveryone

# %%
print("hello", end="!!!")
print("test")
# Out:
# hello!!!test

# %%
a = 123
b = "hello"
print(a, b)
print(a, 456, b, 'world')
# Out:
# 123 hello
# 123 456 hello world

# %%
print('hello "python"')
print("hello 'python'")
print('hello', 'python!')
print("hello + 'python!'")
# Out:
# hello "python"
# hello 'python'
# hello python!
# hello + 'python!'

# %%
print("화면에 직접 출력")
print('ab\'c')
print("ab'c")
print("doesnt")
print('dose')
print('doesn\'t')
print("'staring'")
print("\"string\"")
print("string")
# Out:
# 화면에 직접 출력
# ab'c
# ab'c
# doesnt
# dose
# doesn't
# 'staring'
# "string"
# string

# %%
s1 = '화면에 직접 출력'
s2 = 'ab\'c'
s3 = 'does'
print(s1)
print(s2)
print(s3)
print(s1[0])
print(s2[1])
print(s3[2])
print(s3[1:3])
print(s3[-1])
print(s3[-2])
# Out:
# 화면에 직접 출력
# ab'c
# does
# 화
# b
# e
# oe
# s
# e

# %%
a = 2
b = 3.14
c = a+b
print(a)
print(b)
print(c)
print(round(c, 2))
print("%.2f"%(c)) #소수점 셋째자리까지
print(a+b)
print(a, b, a+b, c)
d = 1e2
e = 1e-2
print(d)
print(e)
# Out:
# 2
# 3.14
# 5.140000000000001
# 5.14
# 5.14
# 5.140000000000001
# 2 3.14 5.140000000000001 5.140000000000001
# 100.0
# 0.01

# %%
item1 = '사과'
price1 = 1000
item2 = '바나나'
price2 = 500
print(item1, price1)
print(item2, price2)

str1 = '{0}은 {1}원 입니다'
print(str1.format(item1, price1))
print(str1.format(item2, price2))

print(item1, price1, sep=',', end='/')
print(item2, price2)

str2 = '%s는 %d원입니다.'
print(str2%(item1, price1))
print(str2%(item2, price2))
# Out:
# 사과 1000
# 바나나 500
# 사과은 1000원 입니다
# 바나나은 500원 입니다
# 사과,1000/바나나 500
# 사과는 1000원입니다.
# 바나나는 500원입니다.
