# %% [markdown]
# <a href="https://colab.research.google.com/github/cjh060331/ABCD-A/blob/20250331/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%B2%A1%ED%84%B0_%ED%95%A9%EA%B3%BC_%EB%82%B4%EC%A0%81%2C_%EC%99%B8%EC%A0%81_%EA%B3%84%EC%82%B0_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2

dot_product = x1 * x2 + y1 * y2

cross_product = x1 * y2 - y1 * x2

print("\n벡터 1:", x1, "i +", y1, "j")
print("벡터 2:", x2, "i +", y2, "j")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product)
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 3
# 첫 번째 벡터의 y 성분을 입력하세요: 5
# 두 번째 벡터의 x 성분을 입력하세요: 6
# 두 번째 벡터의 y 성분을 입력하세요: 8
#
# 벡터 1: 3.0 i + 5.0 j
# 벡터 2: 6.0 i + 8.0 j
#
# 벡터의 합: 9.0 i + 13.0 j
# 벡터의 내적: 58.0
# 벡터의 외적: -6.0

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))
z1 = float(input("첫 번째 벡터의 z 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))
z2 = float(input("두 번째 벡터의 z 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2
sum_z = z1 + z2

dot_product = x1 * x2 + y1 * y2 + z1 * z2

cross_product_x = y1 * z2 - z1 * y2
cross_product_y = z1 * x2 - x1 * z2
cross_product_z = x1 * y2 - y1 * x2

print("\n벡터 1:", x1, "i +", y1, "j +", z1, "k")
print("벡터 2:", x2, "i +", y2, "j +", z2, "k")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j +", sum_z, "k")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product_x, "i +", cross_product_y, "j +", cross_product_z, "k")
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 45
# 첫 번째 벡터의 y 성분을 입력하세요: 24
# 첫 번째 벡터의 z4 성분을 입력하세요: 62
# 두 번째 벡터의 x2 성분을 입력하세요: 35
# 두 번째 벡터의 y2 성분을 입력하세요: 78
# 두 번째 벡터의 z2 성분을 입력하세요: 12
#
# 벡터 1: 45.0 i + 24.0 j + 62.0 k
# 벡터 2: 35.0 i + 78.0 j + 12.0 k
#
# 벡터의 합: 80.0 i + 102.0 j + 74.0 k
# 벡터의 내적: 4191.0
# 벡터의 외적: -4548.0 i + 1630.0 j + 2670.0 k
